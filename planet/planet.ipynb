# %% [markdown]
# ### RapidEye Calibration mock up

# %%
# Import libraries
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('nbagg')

from calibration import Calibration

# %%
# Setup
calibration_information = 'calibration/config/rapideye.json'
non_calibrated_data = 'data/20190601_183500_1056026_RapidEye-2/1056026_2019-06-01_RE2_3A_Analytic_resampled.tif'

calibration = Calibration(calibration_information, non_calibrated_data)

# %%
# Plot original data
plt.imshow(calibration.input_data.Data[4], cmap='Greys_r', vmin=1, vmax=18000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Apply calibration
calibration.apply_calibration()

# %%
# Save calibrated data into a file
calibration.save_calibrated_data('data/calibrated_data.tif')
# Out:
# Python 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 18:10:19)
# Type 'copyright', 'credits' or 'license' for more information
# IPython 6.2.1 -- An enhanced Interactive Python. Type '?' for help.
#
# In [1]: quit()

# %%
# Check if calibrated_data.tif is there
# %ls -l data
# Out:
# total 7276
# drwxrwxr-x 2 glopez glopez    4096 Jun 28 19:51 20190601_183500_1056026_RapidEye-2/
# -rw-rw-r-- 1 glopez glopez 7440593 Jun 30 01:41 calibrated_data.tif
# -rw------- 1 glopez glopez    1830 Jun 28 11:17 README.txt

# %%
# Plot calibrated data
plt.imshow(calibration.calibrated_data[4], cmap='Greys_r', vmin=1, vmax=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
